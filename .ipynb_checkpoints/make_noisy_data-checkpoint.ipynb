# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import shutil
from PIL import Image
from IPython.display import display
import warnings
from sklearn.preprocessing import normalize
warnings.filterwarnings('ignore')

# %%
with Image.open("CATS_DOGS/test/CAT/10000.jpg") as check:
    display(check)
    print(check.size,len(check.mode))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=431x360 at 0x7FE459A71F70>
# (431, 360) 3

# %%
path="CATS_DOGS/"

image_list=[]

for folder, subfolder, files in os.walk(path):
    for file in files:
        image_list.append(folder+"/"+file)

# %%
image_sizes=[]
rejected=[]

for item in image_list:
    try:
        with Image.open(item) as im:
           
            image_sizes.append(im.size)
            if (im.size[0]>=323 and im.size[1]>=302 and len(im.mode)==3):
                shutil.copy(item, os.path.join(f"/Users/rkadhikari/Desktop/Programming practice/CATS_DOGS_denoise/Ground_truth/{os.path.basename(item)}"))
                
    except:
        rejected.append(im)

# %%
print(image_list[1:20])
# Out:
# ['CATS_DOGS/test/CAT/11981.jpg', 'CATS_DOGS/test/CAT/10447.jpg', 'CATS_DOGS/test/CAT/11759.jpg', 'CATS_DOGS/test/CAT/12250.jpg', 'CATS_DOGS/test/CAT/12244.jpg', 'CATS_DOGS/test/CAT/11995.jpg', 'CATS_DOGS/test/CAT/10453.jpg', 'CATS_DOGS/test/CAT/10335.jpg', 'CATS_DOGS/test/CAT/9727.jpg', 'CATS_DOGS/test/CAT/11003.jpg', 'CATS_DOGS/test/CAT/11765.jpg', 'CATS_DOGS/test/CAT/11771.jpg', 'CATS_DOGS/test/CAT/12278.jpg', 'CATS_DOGS/test/CAT/11017.jpg', 'CATS_DOGS/test/CAT/10309.jpg', 'CATS_DOGS/test/CAT/9928.jpg', 'CATS_DOGS/test/CAT/12293.jpg', 'CATS_DOGS/test/CAT/11942.jpg', 'CATS_DOGS/test/CAT/10484.jpg']

# %%
path="CATS_DOGS_denoise/Ground_truth/"

imagelist=[]

for folder, subfolder, filename in os.walk(path):
    for files in filename:
        imagelist.append(folder+files)

# %%
image_size=[]
mode=[]
rejected=[]
for item in imagelist:
    try:
        with Image.open(item) as im:
            image_size.append(im.size)
            mode.append(len(im.mode))
            
    except:
        rejected.append(item)
            
print(len(image_size))   
print(len(rejected))
# Out:
# 11200
# 0

# %%
mode=np.array(mode)
print(sum(mode))
# Out:
# 33600

# %%
transform=transforms.Compose([transforms.CenterCrop(224)])

# %%
for item in imagelist:
    
    gt=Image.open(item)

    gt=np.array(transform(gt))


    gt1=Image.fromarray(gt)
    gt1.save("catdogData/gt/"+os.path.basename(item))
    noisy=gt+np.random.normal(0,40,(224,224,3))

    noisy=np.clip(noisy,0,255).astype(np.uint8)

    noisy=Image.fromarray(noisy)
    noisy.save("catdogData/noise/"+os.path.basename(item))

# %%
"catdogData/"+os.path.basename(imagelist[0])
# Out:
# 'catdogData/9733.jpg'

# %%
plt.imshow(noisy)

# %%
plt.imshow(gt)

# %%
imagesizedf.describe()
# Out:
#                   0             1
# count  24994.000000  24994.000000
# mean     404.493518    361.037129
# std      108.941802     96.936811
# min       42.000000     33.000000
# 25%      323.000000    302.000000
# 50%      448.000000    375.000000
# 75%      500.000000    421.000000
# max      500.000000    500.000000
